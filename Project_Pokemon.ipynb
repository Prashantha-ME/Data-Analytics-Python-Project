# %% [markdown]
# ### **Project_Pokemon**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
import pandas as pd
Pokemon_data = pd.read_csv('https://raw.githubusercontent.com/thecodescholar/DA_Python_Jun_21/main/Dataset/pokemon.csv')
print('Pokemon_data is of type:', type(Pokemon_data))
print('Pokemon_data has shape:', Pokemon_data.shape)
# Out:
# Pokemon_data is of type: <class 'pandas.core.frame.DataFrame'>
# Pokemon_data has shape: (807, 14)

# %%
Pokemon_data
# Out:
#       id      species  generation_id  ...  speed  special-attack  special-defense
# 0      1    bulbasaur              1  ...     45              65               65
# 1      2      ivysaur              1  ...     60              80               80
# 2      3     venusaur              1  ...     80             100              100
# 3      4   charmander              1  ...     65              60               50
# 4      5   charmeleon              1  ...     80              80               65
# ..   ...          ...            ...  ...    ...             ...              ...
# 802  803      poipole              7  ...     73              73               67
# 803  804    naganadel              7  ...    121             127               73
# 804  805    stakataka              7  ...     13              53              101
# 805  806  blacephalon              7  ...    107             151               79
# ...

# %%
Pokemon_data.head(10)
# Out:
#    id     species  generation_id  ...  speed  special-attack  special-defense
# 0   1   bulbasaur              1  ...     45              65               65
# 1   2     ivysaur              1  ...     60              80               80
# 2   3    venusaur              1  ...     80             100              100
# 3   4  charmander              1  ...     65              60               50
# 4   5  charmeleon              1  ...     80              80               65
# 5   6   charizard              1  ...    100             109               85
# 6   7    squirtle              1  ...     43              50               64
# 7   8   wartortle              1  ...     58              65               80
# 8   9   blastoise              1  ...     78              85              105
# 9  10    caterpie              1  ...     45              20               20
#
# [10 rows x 14 columns]

# %%
Pokemon_data.tail(6)
# Out:
#       id      species  generation_id  ...  speed  special-attack  special-defense
# 801  802    marshadow              7  ...    125              90               90
# 802  803      poipole              7  ...     73              73               67
# 803  804    naganadel              7  ...    121             127               73
# 804  805    stakataka              7  ...     13              53              101
# 805  806  blacephalon              7  ...    107             151               79
# 806  807      zeraora              7  ...    143             102               80
#
# [6 rows x 14 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
plt.hist(data = Pokemon_data, x = 'height')
# Out:
# (array([641., 134.,  17.,   8.,   3.,   0.,   3.,   0.,   0.,   1.]),
#  array([ 0.1 ,  1.54,  2.98,  4.42,  5.86,  7.3 ,  8.74, 10.18, 11.62,
#         13.06, 14.5 ]),
#  <a list of 10 Patch objects>)

# %%
sb.countplot(data = Pokemon_data, x = 'weight')
